# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv("housing.csv")

# %%
d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
d.dropna(inplace=True)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x=d.drop(["median_house_value"],axis=1)
y=d["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   ocean_proximity     20433 non-null  object
# dtypes: float64(8), object(1)
# memory usage: 1.6+ MB

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
train_d=x_train.join(y_train)

# %%
train_d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5812     -118.26     34.13                37.0        196.0            74.0
# 846      -122.08     37.58                16.0       3349.0           544.0
# 15957    -122.46     37.71                52.0       1580.0           337.0
# 3572     -118.51     34.24                31.0       5297.0           664.0
# 16976    -122.31     37.57                37.0       1437.0           305.0
# ...          ...       ...                 ...          ...             ...
# 19015    -121.97     38.35                17.0       5678.0          1116.0
# 9066     -118.14     34.72                15.0       2181.0           361.0
# 760      -122.07     37.65                31.0       3300.0           790.0
# 7422     -118.20     33.96                37.0       2127.0           533.0
# 7786     -118.05     33.90                36.0       1047.0           227.0
#
# ...

# %% [markdown]
# To handle the categorical `ocean_proximity` column for correlation calculation, I'll use one-hot encoding. This converts the categorical column into multiple binary columns, making it suitable for numerical operations.

# %%
train_d_encoded = pd.get_dummies(train_d, columns=['ocean_proximity'], drop_first=False)
display(train_d_encoded.head())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5812     -118.26     34.13                37.0        196.0            74.0
# 846      -122.08     37.58                16.0       3349.0           544.0
# 15957    -122.46     37.71                52.0       1580.0           337.0
# 3572     -118.51     34.24                31.0       5297.0           664.0
# 16976    -122.31     37.57                37.0       1437.0           305.0
#
#        population  households  median_income  median_house_value  \
# 5812        194.0        68.0         1.2188            218800.0
# 846        2003.0       488.0         6.0074            236500.0
# 15957      1425.0       330.0         4.0547            246200.0
# 3572       1986.0       657.0         8.6454            483500.0
# 16976       979.0       331.0         4.0000            273700.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# ...

# %% [markdown]
# Now that the categorical column has been one-hot encoded, we can plot the correlation heatmap without errors.

# %%
train_d.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_d_encoded.corr(),annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_d['total_rooms']=np.log(train_d['total_rooms']+1)
train_d['total_bedrooms']=np.log(train_d['total_bedrooms']+1)
train_d['population']=np.log(train_d['population']+1)
train_d['households']=np.log(train_d['households']+1)

# %%
train_d.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_d.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7241
# INLAND        5202
# NEAR OCEAN    2095
# NEAR BAY      1803
# ISLAND           5
# Name: count, dtype: int64

# %%
pd.get_dummies(train_d.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5812        True   False   False     False       False
# 846        False   False   False      True       False
# 15957      False   False   False     False        True
# 3572        True   False   False     False       False
# 16976      False   False   False     False        True
# ...          ...     ...     ...       ...         ...
# 19015      False    True   False     False       False
# 9066       False    True   False     False       False
# 760        False   False   False      True       False
# 7422        True   False   False     False       False
# 7786        True   False   False     False       False
#
# [16346 rows x 5 columns]

# %%
ocean_proximity_binary = pd.get_dummies(train_d['ocean_proximity'], drop_first=False).astype(int)
display(ocean_proximity_binary.head())
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5812           1       0       0         0           0
# 846            0       0       0         1           0
# 15957          0       0       0         0           1
# 3572           1       0       0         0           0
# 16976          0       0       0         0           1

# %%
train_d=train_d.join(ocean_proximity_binary).drop("ocean_proximity",axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_d.corr(),annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=train_d,x="latitude",y="longitude",hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_d['bedroom_ratio']=train_d['total_bedrooms']/train_d['total_rooms']
train_d['household_rooms']=train_d['total_rooms']/train_d['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_d.corr(),annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
x_train,y_train=train_d.drop("median_house_value",axis=1),train_d["median_house_value"]
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Ensure x_test has the exact same columns as x_train in the same order
# This fixes the missing 'ISLAND' category error

for col in x_train.columns:
    if col not in x_test.columns:
        x_test[col] = 0

x_test = x_test[x_train.columns]

print("Columns match:", all(x_test.columns == x_train.columns))
display(x_test.head())
# Out:
# Columns match: True
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18882    -122.25     38.10                52.0     2.138292        1.935031
# 3050     -119.34     35.60                16.0     2.124455        1.907551
# 14727    -117.01     32.79                33.0     2.229804        2.014674
# 11653    -118.03     33.85                16.0     2.141614        1.941430
# 19993    -119.36     36.20                33.0     2.149277        1.944332
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 18882    2.043216    1.911326         2.7500      False   False       0
# 3050     2.069351    1.886268         2.4961      False    True       0
# 14727    2.143709    2.014875         4.3152       True   False       0
# 11653    2.104912    1.941062         3.8426       True   False       0
# 19993    2.110634    1.943973         2.2500      False    True       0
#
# ...

# %%
# x_test and y_test are already correctly prepared in the previous cell (oeQ7CjWvCrbX).
# This cell's operation would overwrite the corrected x_test, hence it's commented out.
# x_test,y_test=test_d.drop("median_house_value",axis=1),test_d["median_house_value"]

# %%
test_d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18882    -122.25     38.10                52.0     2.138292        1.935031
# 3050     -119.34     35.60                16.0     2.124455        1.907551
# 14727    -117.01     32.79                33.0     2.229804        2.014674
# 11653    -118.03     33.85                16.0     2.141614        1.941430
# 19993    -119.36     36.20                33.0     2.149277        1.944332
# ...          ...       ...                 ...          ...             ...
# 10382    -117.65     33.62                15.0     2.186538        1.948563
# 16991    -122.28     37.55                17.0     2.234610        2.007639
# 16855    -122.42     37.62                36.0     2.120930        1.879324
# 14342    -117.17     32.74                39.0     2.223954        2.040353
# 17787    -121.83     37.36                29.0     2.230604        2.052419
#
# ...

# %%
reg.score(x_train,y_train)
# Out:
# 0.6739432288076769

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# Now that features are aligned, we can calculate the score
rf_score = rf.score(x_test, y_test)
print(f'Random Forest R2 Score: {rf_score}')
# Out:
# Random Forest R2 Score: 0.4993487349235558

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    "n_estimators": [3,10,30],
    "max_features": [2,4,6,8]
}
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring="neg_mean_squared_error", return_train_score=True)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [3, 10, 30]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(x_test,y_test)
# Out:
# 0.5068645121589972
